# %%
from prompt_toolkit import filters
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
Unemployment_Dataset = pd.read_csv("F:\\Files\\Docs\\Canada\\St Clair\\DAB103 Project Files\\Data\\Unemployment.csv", skiprows=12, skipfooter=15)

# %%
Unemployment_Dataset
# Out:
#    North American Industry Classification System (NAICS) 4  \
# 0                                                 NaN
# 1                             Total, all industries 5
# 2                            Goods-producing sector 6
# 3                                       Agriculture 7
# 4   Forestry, fishing, mining, quarrying, oil and ...
# 5   Forestry and logging and support activities fo...
# 6                       Fishing, hunting and trapping
# 7     Mining, quarrying, and oil and gas extraction 8
# 8                                           Utilities
# 9                                        Construction
# 10                                      Manufacturing
# 11                                           Durables
# 12                                       Non-durables
# 13                       Services-producing sector 10
# 14                         Wholesale and retail trade
# 15                                    Wholesale trade
# ...

# %%
Unemployment_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   North American Industry Classification System (NAICS) 4  34 non-null     object
#  1   2017                                                     33 non-null     object
#  2   2018                                                     29 non-null     object
#  3   2019                                                     29 non-null     object
#  4   2020                                                     29 non-null     object
#  5   2021                                                     29 non-null     object
#  6   Unnamed: 6                                               0 non-null      float64
#  7   Unnamed: 7                                               0 non-null      float64
# ...

# %%
Unemployment_Annual = pd.read_csv("F:\\Files\\Docs\\Canada\\St Clair\\DAB103 Project Files\\Data\\Unemployment-annual.csv", skiprows=12)

# %%
Unemployment_Annual.head()
# Out:
#    1976  Canada  2016A000011124  Labour force   Total, all industries  \
# 0  1976  Canada  2016A000011124  Labour force  Goods-producing sector
# 1  1976  Canada  2016A000011124  Labour force  Goods-producing sector
# 2  1976  Canada  2016A000011124  Labour force  Goods-producing sector
# 3  1976  Canada  2016A000011124  Labour force  Goods-producing sector
# 4  1976  Canada  2016A000011124  Labour force  Goods-producing sector
#
#       Females  55 years and over  Persons  249  thousands  3  v19668080  \
# 0  Both sexes  15 years and over  Persons  249  thousands  3   v2363354
# 1  Both sexes     15 to 24 years  Persons  249  thousands  3  v19668081
# 2  Both sexes     25 to 54 years  Persons  249  thousands  3  v19668082
# 3  Both sexes  55 years and over  Persons  249  thousands  3  v19668083
# 4       Males  15 years and over  Persons  249  thousands  3   v2363524
#
#    1.1.1.3.4   357.6 Unnamed: 14  Unnamed: 15  Unnamed: 16  1
# ...

# %%
Unemployment_Annual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953820 entries, 0 to 953819
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   1976                   953820 non-null  int64
#  1   Canada                 953820 non-null  object
#  2   2016A000011124         953820 non-null  object
#  3   Labour force           953820 non-null  object
#  4   Total, all industries  953820 non-null  object
#  5   Females                953820 non-null  object
#  6   55 years and over      953820 non-null  object
#  7   Persons                953820 non-null  object
#  8   249                    953820 non-null  int64
#  9   thousands              953820 non-null  object
#  10  3                      953820 non-null  int64
#  11  v19668080              953820 non-null  object
#  12  1.1.1.3.4              953820 non-null  object
#  13  357.6                  676182 non-null  float64
# ...

# %%
Unemployment_Monthly = pd.read_csv("F:\\Files\\Docs\\Canada\\St Clair\\DAB103 Project Files\\Data\\Unemployment-Monthly.csv", skiprows=12, index_col=0)

# %%
Unemployment_Monthly.head()
# Out:
#                                                    January 2017 February 2017  \
# North American Industry Classification System (...
# NaN                                                  Percentage           NaN
# Total, all industries 5                                     7.2           7.0
# Goods-producing sector 6                                    8.2           7.7
# Agriculture 7                                               7.1           7.0
# Forestry, fishing, mining, quarrying, oil and g...         10.1           9.9
#
#                                                    March 2017 April 2017  \
# North American Industry Classification System (...
# NaN                                                       NaN        NaN
# Total, all industries 5                                   7.3        6.8
# Goods-producing sector 6                                  8.0        7.6
# Agriculture 7                                             7.5        6.4
# ...

# %%
Unemployment_Monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, nan to https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1410002201
# Data columns (total 66 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   January 2017    44 non-null     object
#  1   February 2017   30 non-null     object
#  2   March 2017      30 non-null     object
#  3   April 2017      30 non-null     object
#  4   May 2017        30 non-null     object
#  5   June 2017       30 non-null     object
#  6   July 2017       30 non-null     object
#  7   August 2017     29 non-null     object
#  8   September 2017  29 non-null     object
#  9   October 2017    29 non-null     object
#  10  November 2017   29 non-null     object
#  11  December 2017   29 non-null     object
#  12  January 2018    29 non-null     object
#  13  February 2018   29 non-null     object
#  14  March 2018      29 non-null     object
#  15  April 2018      29 non-null     object
# ...

# %%
Unemployment_Monthly.tail()

# %%
Unemployment_Monthly.describe()
# Out:
#        Labour force characteristics Unemployment rate 3 Unnamed: 2 Unnamed: 3  \
# count                            50                  47         31         31
# unique                           50                  44         26         28
# top                               5                 2.9        7.0        4.0
# freq                              1                   2          4          2
#
#        Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# count          31         31         31         31         30         30  ...
# unique         30         26         25         28         26         26  ...
# top           4.0        2.5        3.2        3.1        3.5        3.4  ...
# freq            2          2          2          2          2          3  ...
#
#        Unnamed: 57 Unnamed: 58 Unnamed: 59 Unnamed: 60 Unnamed: 61  \
# count           30          30          30          30          30
# ...

# %%
Unemployment_Monthly.isna().sum().sum()
# Out:
# 1233

# %%
Unemployment_Annual.isna().sum().sum()
# Out:
# 2861460

# %%
Unemployment_Dataset.isna().sum().sum()
# Out:
# 307
