# %%
from prompt_toolkit import filters
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
census_2021 = pd.read_csv('C:/Users/user/Documents/DAB103/DAB103 Project Files/Canada Census 2021.csv')

# %%
census_2021
# Out:
#       REF_DATE      GEO           DGUID     Gender (3a)  Census year (4)  \
# 0         2021   Canada  2021A000011124  Total - Gender             2021
# 1         2021   Canada  2021A000011124  Total - Gender             2021
# 2         2021   Canada  2021A000011124  Total - Gender             2021
# 3         2021   Canada  2021A000011124  Total - Gender             2021
# 4         2021   Canada  2021A000011124  Total - Gender             2021
# ...        ...      ...             ...             ...              ...
# 8575      2021  Nunavut     2021A000262          Women+             2006
# 8576      2021  Nunavut     2021A000262          Women+             2006
# 8577      2021  Nunavut     2021A000262          Women+             2006
# 8578      2021  Nunavut     2021A000262          Women+             2006
# 8579      2021  Nunavut     2021A000262          Women+             2006
#
#                                     Marital status (13) Coordinate  \
# ...

# %%
census_2021.shape
# Out:
# (8580, 39)

# %%
census_2021.describe()
# Out:
#        REF_DATE  Census year (4)  Age (16):Total - Age[1]  Symbol  \
# count    8580.0      8580.000000             8.580000e+03     0.0
# mean     2021.0      2013.500000             2.260446e+05     NaN
# std         0.0         5.590496             1.141907e+06     NaN
# min      2021.0      2006.000000             5.000000e+00     NaN
# 25%      2021.0      2009.750000             3.345000e+03     NaN
# 50%      2021.0      2013.500000             1.692500e+04     NaN
# 75%      2021.0      2017.250000             7.563375e+04     NaN
# max      2021.0      2021.000000             3.097919e+07     NaN
#
#        Age (16):15 to 19 years[2]  Age (16):20 to 24 years[3]  \
# count                8.580000e+03                8.580000e+03
# mean                 1.599483e+04                1.748494e+04
# std                  1.066892e+05                1.021634e+05
# min                  0.000000e+00                0.000000e+00
# ...

# %%
census_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8580 entries, 0 to 8579
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   REF_DATE                        8580 non-null   int64
#  1   GEO                             8580 non-null   object
#  2   DGUID                           8580 non-null   object
#  3   Gender (3a)                     8580 non-null   object
#  4   Census year (4)                 8580 non-null   int64
#  5   Marital status (13)             8580 non-null   object
#  6   Coordinate                      8580 non-null   object
#  7   Age (16):Total - Age[1]         8580 non-null   int64
#  8   Symbol                          0 non-null      float64
#  9   Age (16):15 to 19 years[2]      8580 non-null   int64
#  10  Symbol.1                        1606 non-null   object
#  11  Age (16):20 to 24 years[3]      8580 non-null   int64
# ...

# %%
census_2021.isna().sum().sum()
# Out:
# 134230

# %%
census_2021.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Gender (3a)', 'Census year (4)',
#        'Marital status (13)', 'Coordinate', 'Age (16):Total - Age[1]',
#        'Symbol', 'Age (16):15 to 19 years[2]', 'Symbol.1',
#        'Age (16):20 to 24 years[3]', 'Symbol.2', 'Age (16):25 to 29 years[4]',
#        'Symbol.3', 'Age (16):30 to 34 years[5]', 'Symbol.4',
#        'Age (16):35 to 39 years[6]', 'Symbol.5', 'Age (16):40 to 44 years[7]',
#        'Symbol.6', 'Age (16):45 to 49 years[8]', 'Symbol.7',
#        'Age (16):50 to 54 years[9]', 'Symbol.8', 'Age (16):55 to 59 years[10]',
#        'Symbol.9', 'Age (16):60 to 64 years[11]', 'Symbol.10',
#        'Age (16):65 to 69 years[12]', 'Symbol.11',
#        'Age (16):70 to 74 years[13]', 'Symbol.12',
#        'Age (16):75 to 79 years[14]', 'Symbol.13',
#        'Age (16):80 to 84 years[15]', 'Symbol.14',
#        'Age (16):85 years and over[16]', 'Symbol.15'],
#       dtype='object')

# %%
census_2021.index
# Out:
# RangeIndex(start=0, stop=8580, step=1)

# %%
census_2021.dtypes
# Out:
# REF_DATE                            int64
# GEO                                object
# DGUID                              object
# Gender (3a)                        object
# Census year (4)                     int64
# Marital status (13)                object
# Coordinate                         object
# Age (16):Total - Age[1]             int64
# Symbol                            float64
# Age (16):15 to 19 years[2]          int64
# Symbol.1                           object
# Age (16):20 to 24 years[3]          int64
# Symbol.2                           object
# Age (16):25 to 29 years[4]          int64
# Symbol.3                           object
# Age (16):30 to 34 years[5]          int64
# Symbol.4                           object
# Age (16):35 to 39 years[6]          int64
# Symbol.5                           object
# Age (16):40 to 44 years[7]          int64
# Symbol.6                           object
# Age (16):45 to 49 years[8]          int64
# ...

# %%
census_2021_srt = census_2021.sort_values(['Census year (4)', 'GEO'], ascending = [False, True])
census_2021_srt
# Out:
#       REF_DATE                               GEO         DGUID  \
# 7020      2021  Abbotsford - Mission (CMA), B.C.  2021S0503932
# 7021      2021  Abbotsford - Mission (CMA), B.C.  2021S0503932
# 7022      2021  Abbotsford - Mission (CMA), B.C.  2021S0503932
# 7023      2021  Abbotsford - Mission (CMA), B.C.  2021S0503932
# 7024      2021  Abbotsford - Mission (CMA), B.C.  2021S0503932
# ...        ...                               ...           ...
# 8263      2021                             Yukon   2021A000260
# 8264      2021                             Yukon   2021A000260
# 8265      2021                             Yukon   2021A000260
# 8266      2021                             Yukon   2021A000260
# 8267      2021                             Yukon   2021A000260
#
#          Gender (3a)  Census year (4)  \
# 7020  Total - Gender             2021
# 7021  Total - Gender             2021
# 7022  Total - Gender             2021
# 7023  Total - Gender             2021
# ...

# %%
census_2021_srt.head()
# Out:
#       REF_DATE                               GEO         DGUID  \
# 7020      2021  Abbotsford - Mission (CMA), B.C.  2021S0503932
# 7021      2021  Abbotsford - Mission (CMA), B.C.  2021S0503932
# 7022      2021  Abbotsford - Mission (CMA), B.C.  2021S0503932
# 7023      2021  Abbotsford - Mission (CMA), B.C.  2021S0503932
# 7024      2021  Abbotsford - Mission (CMA), B.C.  2021S0503932
#
#          Gender (3a)  Census year (4)                Marital status (13)  \
# 7020  Total - Gender             2021             Total - Marital status
# 7021  Total - Gender             2021       Married or living common-law
# 7022  Total - Gender             2021                            Married
# 7023  Total - Gender             2021                  Living common-law
# 7024  Total - Gender             2021  Living common law - Never married
#
#      Coordinate  Age (16):Total - Age[1]  Symbol  Age (16):15 to 19 years[2]  \
# ...

# %%
census_2021_2017 = census_2021[census_2021["Census year (4)"]>= 2017]
census_2021_2017
# Out:
#       REF_DATE      GEO           DGUID     Gender (3a)  Census year (4)  \
# 0         2021   Canada  2021A000011124  Total - Gender             2021
# 1         2021   Canada  2021A000011124  Total - Gender             2021
# 2         2021   Canada  2021A000011124  Total - Gender             2021
# 3         2021   Canada  2021A000011124  Total - Gender             2021
# 4         2021   Canada  2021A000011124  Total - Gender             2021
# ...        ...      ...             ...             ...              ...
# 8536      2021  Nunavut     2021A000262          Women+             2021
# 8537      2021  Nunavut     2021A000262          Women+             2021
# 8538      2021  Nunavut     2021A000262          Women+             2021
# 8539      2021  Nunavut     2021A000262          Women+             2021
# 8540      2021  Nunavut     2021A000262          Women+             2021
#
#                                     Marital status (13) Coordinate  \
# ...

# %%
census_2016 = census_2021[census_2021["Census year (4)"] == 2016]
census_2016
# Out:
#       REF_DATE      GEO           DGUID     Gender (3a)  Census year (4)  \
# 13        2021   Canada  2021A000011124  Total - Gender             2016
# 14        2021   Canada  2021A000011124  Total - Gender             2016
# 15        2021   Canada  2021A000011124  Total - Gender             2016
# 16        2021   Canada  2021A000011124  Total - Gender             2016
# 17        2021   Canada  2021A000011124  Total - Gender             2016
# ...        ...      ...             ...             ...              ...
# 8549      2021  Nunavut     2021A000262          Women+             2016
# 8550      2021  Nunavut     2021A000262          Women+             2016
# 8551      2021  Nunavut     2021A000262          Women+             2016
# 8552      2021  Nunavut     2021A000262          Women+             2016
# 8553      2021  Nunavut     2021A000262          Women+             2016
#
#                                     Marital status (13) Coordinate  \
# ...

# %%
sample_data = census_2021_2017[["GEO", "Gender (3a)", "Census year (4)", "Marital status (13)", "Age (16):Total - Age[1]"]]
sample_data
province = ["Alberta", "British Columbia", "Manitoba", "New Brunswick", "Newfoundland and Labrador", "Northwest Territories", "Nova Scotia", "Nunavut", "Ontario", "Prince Edward Island", "Quebec", "Saskatchewan", "Yukon"]
sample_data[sample_data["GEO"].isin(province)].sort_values(["GEO"])
# Out:
#           GEO     Gender (3a)  Census year (4)  \
# 6085  Alberta  Total - Gender             2021
# 6144  Alberta            Men+             2021
# 6145  Alberta            Men+             2021
# 6146  Alberta            Men+             2021
# 6147  Alberta            Men+             2021
# ...       ...             ...              ...
# 8172    Yukon            Men+             2021
# 8171    Yukon            Men+             2021
# 8170    Yukon            Men+             2021
# 8168    Yukon            Men+             2021
# 8228    Yukon          Women+             2021
#
#                                     Marital status (13)  \
# 6085                       Married or living common-law
# 6144              Not married and not living common-law
# 6145  Not married and not living common law - Never ...
# 6146  Not married and not living common law - Separated
# 6147   Not married and not living common law - Divorced
# ...

# %%
province = ["Alberta", "British Columbia", "Manitoba", "New Brunswick", "Newfoundland and Labrador", "Northwest Territories", "Nova Scotia", "Nunavut", "Ontario", "Prince Edward Island", "Quebec", "Saskatchewan", "Yukon"]
census_province_2021 = census_2021_2017[(census_2021_2017["Gender (3a)"] == "Total - Gender") & (census_2021_2017["GEO"].isin(province)) & (census_2021_2017["Census year (4)"] == 2021) & (census_2021_2017["Marital status (13)"] == "Total - Marital status")].sort_values(["GEO"])
census_province_2021
# Out:
#       REF_DATE                        GEO        DGUID     Gender (3a)  \
# 6084      2021                    Alberta  2021A000248  Total - Gender
# 6864      2021           British Columbia  2021A000259  Total - Gender
# 5304      2021                   Manitoba  2021A000246  Total - Gender
# 936       2021              New Brunswick  2021A000213  Total - Gender
# 156       2021  Newfoundland and Labrador  2021A000210  Total - Gender
# 8268      2021      Northwest Territories  2021A000261  Total - Gender
# 624       2021                Nova Scotia  2021A000212  Total - Gender
# 8424      2021                    Nunavut  2021A000262  Total - Gender
# 2652      2021                    Ontario  2021A000235  Total - Gender
# 468       2021       Prince Edward Island  2021A000211  Total - Gender
# 1560      2021                     Quebec  2021A000224  Total - Gender
# 5616      2021               Saskatchewan  2021A000247  Total - Gender
# ...

# %%
census_province_2021.plot(x="GEO", y="Age (16):Total - Age[1]", kind="bar")
# Out:
# <AxesSubplot:xlabel='GEO'>

# %%
province = ["Alberta", "British Columbia", "Manitoba", "New Brunswick", "Newfoundland and Labrador", "Northwest Territories", "Nova Scotia", "Nunavut", "Ontario", "Prince Edward Island", "Quebec", "Saskatchewan", "Yukon"]
census_province_2016 = census_2016[(census_2016["Gender (3a)"] == "Total - Gender") & (census_2016["GEO"].isin(province)) & (census_2016["Census year (4)"] == 2016) & (census_2016["Marital status (13)"] == "Total - Marital status")].sort_values(["GEO"])
census_province_2016
# Out:
#       REF_DATE                        GEO        DGUID     Gender (3a)  \
# 6097      2021                    Alberta  2021A000248  Total - Gender
# 6877      2021           British Columbia  2021A000259  Total - Gender
# 5317      2021                   Manitoba  2021A000246  Total - Gender
# 949       2021              New Brunswick  2021A000213  Total - Gender
# 169       2021  Newfoundland and Labrador  2021A000210  Total - Gender
# 8281      2021      Northwest Territories  2021A000261  Total - Gender
# 637       2021                Nova Scotia  2021A000212  Total - Gender
# 8437      2021                    Nunavut  2021A000262  Total - Gender
# 2665      2021                    Ontario  2021A000235  Total - Gender
# 481       2021       Prince Edward Island  2021A000211  Total - Gender
# 1573      2021                     Quebec  2021A000224  Total - Gender
# 5629      2021               Saskatchewan  2021A000247  Total - Gender
# ...

# %%
census_province_2016.plot(x="GEO", y="Age (16):Total - Age[1]", kind="bar")
# Out:
# <AxesSubplot:xlabel='GEO'>

# %%
census_Canada = census_2021[(census_2021["Gender (3a)"] == "Total - Gender") & (census_2021["GEO"] == "Canada") & (census_2021["Census year (4)"] >= 2000) & (census_2021["Marital status (13)"] == "Total - Marital status")].sort_values(["GEO"])
census_Canada
# Out:
#     REF_DATE     GEO           DGUID     Gender (3a)  Census year (4)  \
# 0       2021  Canada  2021A000011124  Total - Gender             2021
# 13      2021  Canada  2021A000011124  Total - Gender             2016
# 26      2021  Canada  2021A000011124  Total - Gender             2011
# 39      2021  Canada  2021A000011124  Total - Gender             2006
#
#        Marital status (13) Coordinate  Age (16):Total - Age[1]  Symbol  \
# 0   Total - Marital status    1.1.1.1                 30979190     NaN
# 13  Total - Marital status    1.1.2.1                 29312160     NaN
# 26  Total - Marital status    1.1.3.1                 27869345     NaN
# 39  Total - Marital status    1.1.4.1                 26033055     NaN
#
#     Age (16):15 to 19 years[2]  ... Age (16):65 to 69 years[12]  Symbol.11  \
# 0                      2012975  ...                     2210970        NaN
# 13                     2026160  ...                     1972480        NaN
# ...

# %%
census_Canada["census_pop"] = census_Canada["Age (16):Total - Age[1]"]/1000000
census_Canada.plot(x="Census year (4)", y= "census_pop", kind="line", title="Canada Census (2006-2021)", ylabel= "Million")
# Out:
# <AxesSubplot:title={'center':'Canada Census (2006-2021)'}, xlabel='Census year (4)', ylabel='Million'>

# %%
census_2021_2017[census_2021_2017["Gender (3a)"] == "Men+"]
# Out:
#       REF_DATE      GEO           DGUID Gender (3a)  Census year (4)  \
# 52        2021   Canada  2021A000011124        Men+             2021
# 53        2021   Canada  2021A000011124        Men+             2021
# 54        2021   Canada  2021A000011124        Men+             2021
# 55        2021   Canada  2021A000011124        Men+             2021
# 56        2021   Canada  2021A000011124        Men+             2021
# ...        ...      ...             ...         ...              ...
# 8484      2021  Nunavut     2021A000262        Men+             2021
# 8485      2021  Nunavut     2021A000262        Men+             2021
# 8486      2021  Nunavut     2021A000262        Men+             2021
# 8487      2021  Nunavut     2021A000262        Men+             2021
# 8488      2021  Nunavut     2021A000262        Men+             2021
#
#                                     Marital status (13) Coordinate  \
# 52                               Total - Marital status    1.2.1.1
# ...

# %%
census_2021_2017[census_2021_2017["Gender (3a)"] == "Men+"]["Age (16):Total - Age[1]"].sum()
# Out:
# 129410245

# %%
men = census_2021_2017[census_2021_2017["Gender (3a)"] == "Men+"]["Age (16):Total - Age[1]"].sum()
total_gender = census_2021_2017[census_2021_2017["Gender (3a)"] == "Total - Gender"]["Age (16):Total - Age[1]"].sum()

print(men/total_gender)
# Out:
# 0.4885663016741132

# %%
census_2021_2017[census_2021_2017["Gender (3a)"] == "Women+"]
# Out:
#       REF_DATE      GEO           DGUID Gender (3a)  Census year (4)  \
# 104       2021   Canada  2021A000011124      Women+             2021
# 105       2021   Canada  2021A000011124      Women+             2021
# 106       2021   Canada  2021A000011124      Women+             2021
# 107       2021   Canada  2021A000011124      Women+             2021
# 108       2021   Canada  2021A000011124      Women+             2021
# ...        ...      ...             ...         ...              ...
# 8536      2021  Nunavut     2021A000262      Women+             2021
# 8537      2021  Nunavut     2021A000262      Women+             2021
# 8538      2021  Nunavut     2021A000262      Women+             2021
# 8539      2021  Nunavut     2021A000262      Women+             2021
# 8540      2021  Nunavut     2021A000262      Women+             2021
#
#                                     Marital status (13) Coordinate  \
# 104                              Total - Marital status    1.3.1.1
# ...

# %%
women = census_2021_2017[census_2021_2017["Gender (3a)"] == "Women+"]["Age (16):Total - Age[1]"].sum()

print(women/total_gender)
# Out:
# 0.5114339437222973

# %%
print(men/women)
# Out:
# 0.9552872031102397

# %%
census_2021_2017["People in Labour Force"] = census_2021_2017["Age (16):15 to 19 years[2]"] + census_2021_2017["Age (16):20 to 24 years[3]"] + census_2021_2017["Age (16):25 to 29 years[4]"] + census_2021_2017["Age (16):30 to 34 years[5]"] + census_2021_2017["Age (16):35 to 39 years[6]"] + census_2021_2017["Age (16):40 to 44 years[7]"] + census_2021_2017["Age (16):45 to 49 years[8]"] + census_2021_2017["Age (16):50 to 54 years[9]"] + census_2021_2017["Age (16):55 to 59 years[10]"] + census_2021_2017["Age (16):60 to 64 years[11]"]
census_2021_2017["People in Labour Force"]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17132\2105649001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   census_2021_2017["People in Labour Force"] = census_2021_2017["Age (16):15 to 19 years[2]"] + census_2021_2017["Age (16):20 to 24 years[3]"] + census_2021_2017["Age (16):25 to 29 years[4]"] + census_2021_2017["Age (16):30 to 34 years[5]"] + census_2021_2017["Age (16):35 to 39 years[6]"] + census_2021_2017["Age (16):40 to 44 years[7]"] + census_2021_2017["Age (16):45 to 49 years[8]"] + census_2021_2017["Age (16):50 to 54 years[9]"] + census_2021_2017["Age (16):55 to 59 years[10]"] + census_2021_2017["Age (16):60 to 64 years[11]"]
# 0       23957755
# 1       13365080
# 2        9853980
# 3        3511100
# 4        2851490
# ...

# %%
census_2021_2017[census_2021_2017['Gender (3a)'] == "Total - Gender"][["Census year (4)", "Gender (3a)", "Age (16):15 to 19 years[2]", "Age (16):20 to 24 years[3]", "Age (16):25 to 29 years[4]", "Age (16):30 to 34 years[5]", "Age (16):35 to 39 years[6]","Age (16):40 to 44 years[7]", "Age (16):45 to 49 years[8]", "Age (16):50 to 54 years[9]", "Age (16):55 to 59 years[10]", "Age (16):60 to 64 years[11]"]]
# Out:
#       Census year (4)     Gender (3a)  Age (16):15 to 19 years[2]  \
# 0                2021  Total - Gender                     2012975
# 1                2021  Total - Gender                       18970
# 2                2021  Total - Gender                        2285
# 3                2021  Total - Gender                       16690
# 4                2021  Total - Gender                       16690
# ...               ...             ...                         ...
# 8432             2021  Total - Gender                        2860
# 8433             2021  Total - Gender                        2860
# 8434             2021  Total - Gender                           0
# 8435             2021  Total - Gender                           0
# 8436             2021  Total - Gender                           0
#
#       Age (16):20 to 24 years[3]  Age (16):25 to 29 years[4]  \
# 0                        2202260                     2421505
# ...

# %%
census_2021_2017[['Gender (3a)']] == "Total - Gender"
# Out:
#       Gender (3a)
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# ...           ...
# 8536        False
# 8537        False
# 8538        False
# 8539        False
# 8540        False
#
# [2145 rows x 1 columns]

# %%
census_2021_2017[(census_2021_2017["Gender (3a)"] == "Women+") & (census_2021_2017["GEO"] == "Canada")]
# Out:
#      REF_DATE     GEO           DGUID Gender (3a)  Census year (4)  \
# 104      2021  Canada  2021A000011124      Women+             2021
# 105      2021  Canada  2021A000011124      Women+             2021
# 106      2021  Canada  2021A000011124      Women+             2021
# 107      2021  Canada  2021A000011124      Women+             2021
# 108      2021  Canada  2021A000011124      Women+             2021
# 109      2021  Canada  2021A000011124      Women+             2021
# 110      2021  Canada  2021A000011124      Women+             2021
# 111      2021  Canada  2021A000011124      Women+             2021
# 112      2021  Canada  2021A000011124      Women+             2021
# 113      2021  Canada  2021A000011124      Women+             2021
# 114      2021  Canada  2021A000011124      Women+             2021
# 115      2021  Canada  2021A000011124      Women+             2021
# 116      2021  Canada  2021A000011124      Women+             2021
#
# ...

# %%
census_2021_2017[(census_2021_2017["Gender (3a)"] == "Women+") & (census_2021_2017["GEO"] == "Canada")]["People in Labour Force"].sum()
# Out:
# 37910715

# %%
census_2021_2017[(census_2021_2017["Gender (3a)"] == "Men+") & (census_2021_2017["GEO"] == "Canada")]
# Out:
#     REF_DATE     GEO           DGUID Gender (3a)  Census year (4)  \
# 52      2021  Canada  2021A000011124        Men+             2021
# 53      2021  Canada  2021A000011124        Men+             2021
# 54      2021  Canada  2021A000011124        Men+             2021
# 55      2021  Canada  2021A000011124        Men+             2021
# 56      2021  Canada  2021A000011124        Men+             2021
# 57      2021  Canada  2021A000011124        Men+             2021
# 58      2021  Canada  2021A000011124        Men+             2021
# 59      2021  Canada  2021A000011124        Men+             2021
# 60      2021  Canada  2021A000011124        Men+             2021
# 61      2021  Canada  2021A000011124        Men+             2021
# 62      2021  Canada  2021A000011124        Men+             2021
# 63      2021  Canada  2021A000011124        Men+             2021
# 64      2021  Canada  2021A000011124        Men+             2021
#
# ...

# %%
census_2021_2017[(census_2021_2017["Gender (3a)"] == "Men+") & (census_2021_2017["GEO"] == "Canada")]["People in Labour Force"].sum()
# Out:
# 37473645

# %%
#census_2021_2017.groupby(["GEO", "Gender (3a)"])["People in Labour Force"].sum()
#print(labour_force_per_region)

# %%
labour_force_per_region = census_2021_2017[["GEO", "Gender (3a)", "People in Labour Force"]]

# %%
women_in_labour_force = labour_force_per_region[labour_force_per_region["Gender (3a)"] == "Women+"].groupby("GEO")

# %%
print(women_in_labour_force["People in Labour Force"].sum())
# Out:
# GEO
# Abbotsford - Mission (CMA), B.C.                  193320
# Alberta                                          4376460
# Barrie (CMA), Ont.                                223135
# Belleville - Quinte West (CMA), Ont.              108485
# Brantford (CMA), Ont.                             144175
# British Columbia                                 5151885
# Calgary (CMA), Alta.                             1567475
# Canada                                          37910715
# Chilliwack (CMA), B.C.                            108400
# Drummondville (CMA), Que.                         101745
# Edmonton (CMA), Alta.                            1470685
# Fredericton (CMA), N.B.                           113295
# Greater Sudbury (CMA), Ont.                       173660
# Guelph (CMA), Ont.                                174340
# Halifax (CMA), N.S.                               503885
# Hamilton (CMA), Ont.                              799780
# ...

# %%
men_in_labour_force = labour_force_per_region[labour_force_per_region["Gender (3a)"] == "Men+"].groupby("GEO")

# %%
print(men_in_labour_force["People in Labour Force"].sum())
# Out:
# GEO
# Abbotsford - Mission (CMA), B.C.                  196425
# Alberta                                          4403055
# Barrie (CMA), Ont.                                222050
# Belleville - Quinte West (CMA), Ont.              107905
# Brantford (CMA), Ont.                             142355
# British Columbia                                 5030785
# Calgary (CMA), Alta.                             1557855
# Canada                                          37473645
# Chilliwack (CMA), B.C.                            106970
# Drummondville (CMA), Que.                         105330
# Edmonton (CMA), Alta.                            1479185
# Fredericton (CMA), N.B.                           110445
# Greater Sudbury (CMA), Ont.                       172855
# Guelph (CMA), Ont.                                171140
# Halifax (CMA), N.S.                               488840
# Hamilton (CMA), Ont.                              782665
# ...

# %%
immigration = pd.read_csv('C:/Users/user/Documents/DAB103/DAB103 Project Files/components of migration-annual.csv')
immigration
# Out:
# C:\Users\felix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (13,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           REF_DATE      GEO           DGUID         Sex  \
# 0        1971/1972   Canada  2016A000011124  Both sexes
# 1        1971/1972   Canada  2016A000011124  Both sexes
# 2        1971/1972   Canada  2016A000011124  Both sexes
# 3        1971/1972   Canada  2016A000011124  Both sexes
# 4        1971/1972   Canada  2016A000011124  Both sexes
# ...            ...      ...             ...         ...
# 1288375  2021/2022  Nunavut     2016A000262     Females
# 1288376  2021/2022  Nunavut     2016A000262     Females
# 1288377  2021/2022  Nunavut     2016A000262     Females
# 1288378  2021/2022  Nunavut     2016A000262     Females
# 1288379  2021/2022  Nunavut     2016A000262     Females
#
# ...

# %%
immigration.shape
# Out:
# (1288380, 17)

# %%
immigration.describe()
# Out:
#           UOM_ID  SCALAR_ID         VALUE  SYMBOL   DECIMALS
# count  1288380.0  1288380.0  1.261080e+06     0.0  1288380.0
# mean       249.0        0.0  4.915924e+02     NaN        0.0
# std          0.0        0.0  4.737347e+03     NaN        0.0
# min        249.0        0.0 -7.118500e+04     NaN        0.0
# 25%        249.0        0.0  0.000000e+00     NaN        0.0
# 50%        249.0        0.0  3.000000e+00     NaN        0.0
# 75%        249.0        0.0  4.900000e+01     NaN        0.0
# max        249.0        0.0  4.929840e+05     NaN        0.0

# %%
immigration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1288380 entries, 0 to 1288379
# Data columns (total 17 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   REF_DATE         1288380 non-null  object
#  1   GEO              1288380 non-null  object
#  2   DGUID            1258380 non-null  object
#  3   Sex              1288380 non-null  object
#  4   Type of migrant  1288380 non-null  object
#  5   Age group        1288380 non-null  object
#  6   UOM              1288380 non-null  object
#  7   UOM_ID           1288380 non-null  int64
#  8   SCALAR_FACTOR    1288380 non-null  object
#  9   SCALAR_ID        1288380 non-null  int64
#  10  VECTOR           1288380 non-null  object
#  11  COORDINATE       1288380 non-null  object
#  12  VALUE            1261080 non-null  float64
#  13  STATUS           27300 non-null    object
#  14  SYMBOL           0 non-null        float64
#  15  TERMINATED       30000 non-null    object
# ...

# %%
immigration.isna().sum().sum()
# Out:
# 3865140

# %%
immigration.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Sex', 'Type of migrant', 'Age group',
#        'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE',
#        'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
immigration.index
# Out:
# RangeIndex(start=0, stop=1288380, step=1)

# %%
immigration_2021_2017 = immigration[immigration["REF_DATE"] > "2016"]
immigration_2021_2017
# Out:
#           REF_DATE      GEO           DGUID         Sex  \
# 1114500  2016/2017   Canada  2016A000011124  Both sexes
# 1114501  2016/2017   Canada  2016A000011124  Both sexes
# 1114502  2016/2017   Canada  2016A000011124  Both sexes
# 1114503  2016/2017   Canada  2016A000011124  Both sexes
# 1114504  2016/2017   Canada  2016A000011124  Both sexes
# ...            ...      ...             ...         ...
# 1288375  2021/2022  Nunavut     2016A000262     Females
# 1288376  2021/2022  Nunavut     2016A000262     Females
# 1288377  2021/2022  Nunavut     2016A000262     Females
# 1288378  2021/2022  Nunavut     2016A000262     Females
# 1288379  2021/2022  Nunavut     2016A000262     Females
#
#                      Type of migrant          Age group      UOM  UOM_ID  \
# 1114500                   Immigrants           All ages  Persons     249
# 1114501                   Immigrants            -1 year  Persons     249
# ...

# %%
immigrants_2021_2017 = immigration_2021_2017[immigration_2021_2017["Type of migrant"] == "Immigrants"]
immigrants_2021_2017
# Out:
#           REF_DATE      GEO           DGUID         Sex Type of migrant  \
# 1114500  2016/2017   Canada  2016A000011124  Both sexes      Immigrants
# 1114501  2016/2017   Canada  2016A000011124  Both sexes      Immigrants
# 1114502  2016/2017   Canada  2016A000011124  Both sexes      Immigrants
# 1114503  2016/2017   Canada  2016A000011124  Both sexes      Immigrants
# 1114504  2016/2017   Canada  2016A000011124  Both sexes      Immigrants
# ...            ...      ...             ...         ...             ...
# 1287823  2021/2022  Nunavut     2016A000262     Females      Immigrants
# 1287824  2021/2022  Nunavut     2016A000262     Females      Immigrants
# 1287825  2021/2022  Nunavut     2016A000262     Females      Immigrants
# 1287826  2021/2022  Nunavut     2016A000262     Females      Immigrants
# 1287827  2021/2022  Nunavut     2016A000262     Females      Immigrants
#
#                  Age group      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID   VECTOR  \
# ...

# %%
women_immigrants = immigrants_2021_2017[immigrants_2021_2017["Sex"] == "Females"]
women_immigrants
# Out:
#           REF_DATE      GEO           DGUID      Sex Type of migrant  \
# 1115880  2016/2017   Canada  2016A000011124  Females      Immigrants
# 1115881  2016/2017   Canada  2016A000011124  Females      Immigrants
# 1115882  2016/2017   Canada  2016A000011124  Females      Immigrants
# 1115883  2016/2017   Canada  2016A000011124  Females      Immigrants
# 1115884  2016/2017   Canada  2016A000011124  Females      Immigrants
# ...            ...      ...             ...      ...             ...
# 1287823  2021/2022  Nunavut     2016A000262  Females      Immigrants
# 1287824  2021/2022  Nunavut     2016A000262  Females      Immigrants
# 1287825  2021/2022  Nunavut     2016A000262  Females      Immigrants
# 1287826  2021/2022  Nunavut     2016A000262  Females      Immigrants
# 1287827  2021/2022  Nunavut     2016A000262  Females      Immigrants
#
#                  Age group      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID   VECTOR  \
# ...

# %%
women_immigrants["VALUE"].sum()
# Out:
# 17523786.0

# %%
women_immigrants[women_immigrants["Age group"] == "15 to 64 years"]
# Out:
#           REF_DATE                        GEO           DGUID      Sex  \
# 1116008  2016/2017                     Canada  2016A000011124  Females
# 1118078  2016/2017  Newfoundland and Labrador     2016A000210  Females
# 1120148  2016/2017       Prince Edward Island     2016A000211  Females
# 1122218  2016/2017                Nova Scotia     2016A000212  Females
# 1124288  2016/2017              New Brunswick     2016A000213  Females
# ...            ...                        ...             ...      ...
# 1279538  2021/2022                    Alberta     2016A000248  Females
# 1281608  2021/2022           British Columbia     2016A000259  Females
# 1283678  2021/2022                      Yukon     2016A000260  Females
# 1285748  2021/2022      Northwest Territories     2016A000261  Females
# 1287818  2021/2022                    Nunavut     2016A000262  Females
#
#         Type of migrant       Age group      UOM  UOM_ID SCALAR_FACTOR  \
# ...

# %%
women_immigrants[women_immigrants["Age group"] == "15 to 64 years"]["VALUE"].sum()
# Out:
# 1512896.0

# %%
women_immigrants_per_region = women_immigrants[["GEO", "Age group", "VALUE"]]
print(women_immigrants_per_region)
# Out:
#              GEO          Age group     VALUE
# 1115880   Canada           All ages  140934.0
# 1115881   Canada            -1 year     337.0
# 1115882   Canada       0 to 4 years    8984.0
# 1115883   Canada            0 years    1588.0
# 1115884   Canada             1 year    1617.0
# ...          ...                ...       ...
# 1287823  Nunavut     18 to 64 years      25.0
# 1287824  Nunavut     25 to 44 years      19.0
# 1287825  Nunavut     45 to 64 years       4.0
# 1287826  Nunavut  65 years and over       0.0
# 1287827  Nunavut  90 years and over       0.0
#
# [11592 rows x 3 columns]

# %%
women_immigrants_per_region[women_immigrants_per_region["Age group"] == "15 to 64 years"]
# Out:
#                                GEO       Age group     VALUE
# 1116008                     Canada  15 to 64 years  107733.0
# 1118078  Newfoundland and Labrador  15 to 64 years     389.0
# 1120148       Prince Edward Island  15 to 64 years     761.0
# 1122218                Nova Scotia  15 to 64 years    1545.0
# 1124288              New Brunswick  15 to 64 years    1206.0
# ...                            ...             ...       ...
# 1279538                    Alberta  15 to 64 years   20646.0
# 1281608           British Columbia  15 to 64 years   35927.0
# 1283678                      Yukon  15 to 64 years     273.0
# 1285748      Northwest Territories  15 to 64 years     138.0
# 1287818                    Nunavut  15 to 64 years      26.0
#
# [84 rows x 3 columns]

# %%
men_immigrants = immigrants_2021_2017[immigrants_2021_2017["Sex"] == "Males"]
men_immigrants
# Out:
#           REF_DATE      GEO           DGUID    Sex Type of migrant  \
# 1115190  2016/2017   Canada  2016A000011124  Males      Immigrants
# 1115191  2016/2017   Canada  2016A000011124  Males      Immigrants
# 1115192  2016/2017   Canada  2016A000011124  Males      Immigrants
# 1115193  2016/2017   Canada  2016A000011124  Males      Immigrants
# 1115194  2016/2017   Canada  2016A000011124  Males      Immigrants
# ...            ...      ...             ...    ...             ...
# 1287133  2021/2022  Nunavut     2016A000262  Males      Immigrants
# 1287134  2021/2022  Nunavut     2016A000262  Males      Immigrants
# 1287135  2021/2022  Nunavut     2016A000262  Males      Immigrants
# 1287136  2021/2022  Nunavut     2016A000262  Males      Immigrants
# 1287137  2021/2022  Nunavut     2016A000262  Males      Immigrants
#
#                  Age group      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID   VECTOR  \
# 1115190           All ages  Persons     249         units          0  v437340
# ...

# %%
men_immigrants["VALUE"].sum()
# Out:
# 17274138.0

# %%
men_immigrants[men_immigrants["Age group"] == "15 to 64 years"]
# Out:
#           REF_DATE                        GEO           DGUID    Sex  \
# 1115318  2016/2017                     Canada  2016A000011124  Males
# 1117388  2016/2017  Newfoundland and Labrador     2016A000210  Males
# 1119458  2016/2017       Prince Edward Island     2016A000211  Males
# 1121528  2016/2017                Nova Scotia     2016A000212  Males
# 1123598  2016/2017              New Brunswick     2016A000213  Males
# ...            ...                        ...             ...    ...
# 1278848  2021/2022                    Alberta     2016A000248  Males
# 1280918  2021/2022           British Columbia     2016A000259  Males
# 1282988  2021/2022                      Yukon     2016A000260  Males
# 1285058  2021/2022      Northwest Territories     2016A000261  Males
# 1287128  2021/2022                    Nunavut     2016A000262  Males
#
#         Type of migrant       Age group      UOM  UOM_ID SCALAR_FACTOR  \
# ...

# %%
men_immigrants[men_immigrants["Age group"] == "15 to 64 years"]["VALUE"].sum()
# Out:
# 1478922.0

# %%
gdp_bp = pd.read_csv('C:/Users/user/Documents/DAB103/DAB103 Project Files/GDP at basic prices (Q1 2016 - Q2 2022).csv', skiprows=11) #the no of rows had to be skipped in order to load the datset.
gdp_bp
# Out:
#    North American Industry Classification System (NAICS)  \
# 0                                                 NaN
# 1                            All industries  [T001] 4
# 2                Goods-producing industries  [T002] 4
# 3              Service-producing industries  [T003] 4
# 4                  Business sector industries  [T004]
# 5              Non-business sector industries  [T007]
# 6                     Industrial production  [T010] 4
# 7      Non-durable manufacturing industries  [T011] 4
# 8          Durable manufacturing industries  [T012] 4
# 9   Information and communication technology secto...
# 10                            Energy sector  [T016] 4
# 11  Industrial production (1950 definition)  [T017] 4
# 12                            Public Sector  [T018] 4
# 13                 Content and media sector  [T019] 4
# 14  All industries (except cannabis sector)  [T020] 4
# 15                          Cannabis sector  [T021] 4
# ...

# %%
gdp_bp.head()
# Out:
#   North American Industry Classification System (NAICS)    Q1 2016    Q2 2016  \
# 0                                                NaN       Dollars        NaN
# 1                           All industries  [T001] 4     1,832,100  1,826,026
# 2               Goods-producing industries  [T002] 4       542,743    533,115
# 3             Service-producing industries  [T003] 4     1,288,035  1,290,578
# 4                 Business sector industries  [T004]     1,507,581  1,499,392
#
#      Q3 2016    Q4 2016    Q1 2017    Q2 2017    Q3 2017    Q4 2017  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1  1,843,592  1,853,250  1,872,772  1,893,534  1,901,941  1,915,361
# 2    542,337    546,269    552,758    560,301    563,229    567,383
# 3  1,299,390  1,305,209  1,318,353  1,331,712  1,337,223  1,346,459
# 4  1,516,462  1,525,689  1,545,004  1,564,534  1,569,925  1,581,177
#
#      Q1 2018  ...    Q1 2020    Q2 2020    Q3 2020    Q4 2020    Q1 2021  \
# ...

# %%
gdp_bp.tail()
# Out:
#    North American Industry Classification System (NAICS)  \
# 42                                                  2
# 43                                                  3
# 44                                                  4
# 45  How to cite: Statistics Canada. Table 36-10-04...
# 46  https://www150.statcan.gc.ca/t1/tbl1/en/tv.act...
#
#                                               Q1 2016 Q2 2016 Q3 2016 Q4 2016  \
# 42  At the lowest level of detail, it may not be p...     NaN     NaN     NaN
# 43  Effective November 30, 2018 the data is presen...     NaN     NaN     NaN
# 44  The alphanumeric code appearing in square brac...     NaN     NaN     NaN
# 45                                                NaN     NaN     NaN     NaN
# 46                                                NaN     NaN     NaN     NaN
#
#    Q1 2017 Q2 2017 Q3 2017 Q4 2017 Q1 2018  ... Q1 2020 Q2 2020 Q3 2020  \
# 42     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# ...

# %%
#The footnotes will be skipped or dropped during the cleaning phase.

# %%
gdp_bp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 27 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   North American Industry Classification System (NAICS)  46 non-null     object
#  1   Q1 2016                                                43 non-null     object
#  2   Q2 2016                                                36 non-null     object
#  3   Q3 2016                                                36 non-null     object
#  4   Q4 2016                                                36 non-null     object
#  5   Q1 2017                                                36 non-null     object
#  6   Q2 2017                                                36 non-null     object
#  7   Q3 2017                                                36 non-null     object
# ...

# %%
gdp_bp.isna().sum()
# Out:
# North American Industry Classification System (NAICS)     1
# Q1 2016                                                   4
# Q2 2016                                                  11
# Q3 2016                                                  11
# Q4 2016                                                  11
# Q1 2017                                                  11
# Q2 2017                                                  11
# Q3 2017                                                  11
# Q4 2017                                                  11
# Q1 2018                                                  11
# Q2 2018                                                  11
# Q3 2018                                                  11
# Q4 2018                                                  11
# Q1 2019                                                  11
# Q2 2019                                                  11
# Q3 2019                                                  11
# ...

# %%
#NAs have been identified in each dataset and will be dropped in the next phase

# %%
#gdp_bp = gdp_bp.dropna() #The first row has NAs so we are dropping them
#gdp_bp

# %%
#gdp_bp.info()

# %%
gdp_bp.describe()
# Out:
#        North American Industry Classification System (NAICS)  Q1 2016  \
# count                                                  46          43
# unique                                                 46          43
# top                              All industries  [T001] 4     Dollars
# freq                                                    1           1
#
#           Q2 2016    Q3 2016    Q4 2016    Q1 2017    Q2 2017    Q3 2017  \
# count          36         36         36         36         36         36
# unique         36         36         36         36         36         36
# top     1,826,026  1,843,592  1,853,250  1,872,772  1,893,534  1,901,941
# freq            1          1          1          1          1          1
#
#           Q4 2017    Q1 2018  ...    Q1 2020    Q2 2020    Q3 2020    Q4 2020  \
# count          36         36  ...         36         36         36         36
# unique         36         36  ...         36         36         36         36
# ...

# %%
#The Dtype are all objects, hence the describe function could not print out the mean, median, miin, max and st. The columns will be converted into a integer in order to perform further data exploration in the next phase

# %%
#The columns will be renamed by removing the spaces inbetween the characters and converting them to lowercase

# %%
gdp_bp[['North American Industry Classification System (NAICS)', 'Q1 2016', 'Q2 2022']]
# Out:
#    North American Industry Classification System (NAICS)  \
# 0                                                 NaN
# 1                            All industries  [T001] 4
# 2                Goods-producing industries  [T002] 4
# 3              Service-producing industries  [T003] 4
# 4                  Business sector industries  [T004]
# 5              Non-business sector industries  [T007]
# 6                     Industrial production  [T010] 4
# 7      Non-durable manufacturing industries  [T011] 4
# 8          Durable manufacturing industries  [T012] 4
# 9   Information and communication technology secto...
# 10                            Energy sector  [T016] 4
# 11  Industrial production (1950 definition)  [T017] 4
# 12                            Public Sector  [T018] 4
# 13                 Content and media sector  [T019] 4
# 14  All industries (except cannabis sector)  [T020] 4
# 15                          Cannabis sector  [T021] 4
# ...

# %%
gdp_expense = pd.read_csv('C:/Users/user/Documents/DAB103/DAB103 Project Files/GDP expense (Q1 2017 - Q2 2022).csv', skiprows= 11) # skip the nrows in order to read file
gdp_expense
# Out:
#                                             Estimates    Q1 2017    Q2 2017  \
# 0                                                 NaN    Dollars        NaN
# 1                       Final consumption expenditure  1,550,415  1,565,408
# 2             Household final consumption expenditure  1,119,347  1,134,136
# 3                                               Goods    503,370    513,363
# 4                                       Durable goods    149,665    153,250
# 5                                  Semi-durable goods     81,721     83,763
# 6                                   Non-durable goods    272,018    276,380
# 7                                            Services    616,070    621,007
# 8   Non-profit institutions serving households' fi...     29,652     29,644
# 9   General governments final consumption expenditure    401,743    402,064
# 10                      Gross fixed capital formation    425,595    429,324
# ...

# %%
gdp_expense.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 23 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Estimates  33 non-null     object
#  1   Q1 2017    32 non-null     object
#  2   Q2 2017    31 non-null     object
#  3   Q3 2017    31 non-null     object
#  4   Q4 2017    31 non-null     object
#  5   Q1 2018    31 non-null     object
#  6   Q2 2018    31 non-null     object
#  7   Q3 2018    31 non-null     object
#  8   Q4 2018    31 non-null     object
#  9   Q1 2019    31 non-null     object
#  10  Q2 2019    31 non-null     object
#  11  Q3 2019    31 non-null     object
#  12  Q4 2019    31 non-null     object
#  13  Q1 2020    31 non-null     object
#  14  Q2 2020    31 non-null     object
#  15  Q3 2020    31 non-null     object
#  16  Q4 2020    31 non-null     object
#  17  Q1 2021    31 non-null     object
#  18  Q2 2021    31 non-null     object
# ...

# %%
gdp_expense.shape
# Out:
# (34, 23)

# %%
gdp_expense.isna().sum()
# Out:
# Estimates    1
# Q1 2017      2
# Q2 2017      3
# Q3 2017      3
# Q4 2017      3
# Q1 2018      3
# Q2 2018      3
# Q3 2018      3
# Q4 2018      3
# Q1 2019      3
# Q2 2019      3
# Q3 2019      3
# Q4 2019      3
# Q1 2020      3
# Q2 2020      3
# Q3 2020      3
# Q4 2020      3
# Q1 2021      3
# Q2 2021      3
# Q3 2021      3
# Q4 2021      3
# Q1 2022      3
# Q2 2022      3
# dtype: int64

# %%
#NAs have been identifed and will removed in the next phase of the project. Also the data type for the dataset are all objects, though it contains numbers. This will be cleaned at the project's next phase

# %%
gdp_expense.columns
# Out:
# Index(['Estimates', 'Q1 2017', 'Q2 2017', 'Q3 2017', 'Q4 2017', 'Q1 2018',
#        'Q2 2018', 'Q3 2018', 'Q4 2018', 'Q1 2019', 'Q2 2019', 'Q3 2019',
#        'Q4 2019', 'Q1 2020', 'Q2 2020', 'Q3 2020', 'Q4 2020', 'Q1 2021',
#        'Q2 2021', 'Q3 2021', 'Q4 2021', 'Q1 2022', 'Q2 2022'],
#       dtype='object')

# %%
gdp_expense.index
# Out:
# RangeIndex(start=0, stop=34, step=1)

# %%
#column names should be renamed to the format "q1_2017"

# %%
gdp_expense[['Estimates','Q1 2017', 'Q2 2022']]
# Out:
#                                             Estimates    Q1 2017    Q2 2022
# 0                                                 NaN    Dollars        NaN
# 1                       Final consumption expenditure  1,550,415  1,719,628
# 2             Household final consumption expenditure  1,119,347  1,230,930
# 3                                               Goods    503,370    562,512
# 4                                       Durable goods    149,665    156,778
# 5                                  Semi-durable goods     81,721    104,505
# 6                                   Non-durable goods    272,018    302,257
# 7                                            Services    616,070    670,491
# 8   Non-profit institutions serving households' fi...     29,652     32,572
# 9   General governments final consumption expenditure    401,743    455,909
# 10                      Gross fixed capital formation    425,595    458,659
# ...

# %%
gdp_income = pd.read_csv('C:/Users/user/Documents/DAB103/DAB103 Project Files/GDP income (Q1 2017 - Q2 2022).csv')
gdp_income
# Out:
#    Gross domestic product, income-based, quarterly (x 1,000,000)  \
# 0                                Frequency: Quarterly
# 1     Table: 36-10-0103-01 (formerly CANSIM 380-0063)
# 2                            Release date: 2022-08-31
# 3                                   Geography: Canada
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                 Seasonal adjustment
# 8                                           Geography
# 9                                           Estimates
# 10                                                NaN
# 11                          Compensation of employees
# 12                                 Wages and salaries
# 13                    Employers' social contributions
# 14                            Gross operating surplus
# 15                Net operating surplus: corporations
# ...

# %%
#the NAs can be removed by passing the function dropna() or skip rows and footer
#The columns are not properly labelled

# %%
gdp_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 23 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Gross domestic product, income-based, quarterly (x 1,000,000)  25 non-null     object
#  1   Unnamed: 1                                                     19 non-null     object
#  2   Unnamed: 2                                                     16 non-null     object
#  3   Unnamed: 3                                                     15 non-null     object
#  4   Unnamed: 4                                                     15 non-null     object
#  5   Unnamed: 5                                                     15 non-null     object
#  6   Unnamed: 6                                                     15 non-null     object
# ...

# %%
#the datdtype are all objects. The datatype for the columns with numeric values will be changed during the data cleaning process.

# %%
gdp_income.isna().any()
# Out:
# Estimates    False
# Q1 2017      False
# Q2 2017      False
# Q3 2017      False
# Q4 2017      False
# Q1 2018      False
# Q2 2018      False
# Q3 2018      False
# Q4 2018      False
# Q1 2019      False
# Q2 2019      False
# Q3 2019      False
# Q4 2019      False
# Q1 2020      False
# Q2 2020      False
# Q3 2020      False
# Q4 2020      False
# Q1 2021      False
# Q2 2021      False
# Q3 2021      False
# Q4 2021      False
# Q1 2022      False
# Q2 2022      False
# dtype: bool

# %%
gdp_income.isna().sum()
# Out:
# Gross domestic product, income-based, quarterly (x 1,000,000)    11
# Unnamed: 1                                                       17
# Unnamed: 2                                                       20
# Unnamed: 3                                                       21
# Unnamed: 4                                                       21
# Unnamed: 5                                                       21
# Unnamed: 6                                                       21
# Unnamed: 7                                                       21
# Unnamed: 8                                                       21
# Unnamed: 9                                                       21
# Unnamed: 10                                                      21
# Unnamed: 11                                                      21
# Unnamed: 12                                                      21
# Unnamed: 13                                                      21
# ...

# %%
gdp_income.isna().sum().sum()  #total numnber of NAs in the dataset

# %%
gdp_income.shape
# Out:
# (36, 23)

# %%
gdp_income.head() # the NAs will be cleaned/dropped during the cleaning phase

# %%
gdp_income.sample(10)
# Out:
#    Gross domestic product, income-based, quarterly (x 1,000,000)  \
# 3                                   Geography: Canada
# 17  Consumption of fixed capital: general governme...
# 7                                 Seasonal adjustment
# 18                                 Gross mixed income
# 29                                         Footnotes:
# 10                                                NaN
# 20  Consumption of fixed capital: unincorporated b...
# 1     Table: 36-10-0103-01 (formerly CANSIM 380-0063)
# 12                                 Wages and salaries
# 33                                                NaN
#
#                              Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 3                                   NaN        NaN        NaN        NaN
# 17                               70,468     71,144     70,996     71,548
# 7   Seasonally adjusted at annual rates        NaN        NaN        NaN
# ...

# %%
gdp_income.dtypes
# Out:
# Gross domestic product, income-based, quarterly (x 1,000,000)    object
# Unnamed: 1                                                       object
# Unnamed: 2                                                       object
# Unnamed: 3                                                       object
# Unnamed: 4                                                       object
# Unnamed: 5                                                       object
# Unnamed: 6                                                       object
# Unnamed: 7                                                       object
# Unnamed: 8                                                       object
# Unnamed: 9                                                       object
# Unnamed: 10                                                      object
# Unnamed: 11                                                      object
# Unnamed: 12                                                      object
# ...

# %%
gdp_income = pd.read_csv('C:/Users/user/Documents/DAB103/DAB103 Project Files/GDP income (Q1 2017 - Q2 2022).csv', skiprows=10, skipfooter=11,engine='python').dropna()
gdp_income
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-79-d33552bf976e> in <module>
# ----> 1 gdp_income = pd.read_csv('C:/Users/user/Documents/DAB103/DAB103 Project Files/GDP income (Q1 2017 - Q2 2022).csv', skiprows=10, skipfooter=11,engine='python').dropna()
#       2 gdp_income
#
# ...

# %%
gdp_income[['Estimates', 'Q4 2017', 'Q4 2018', 'Q4 2019', 'Q4 2020', 'Q4 2021', 'Q2 2022']]
# Out:
#                                             Estimates    Q4 2017    Q4 2018  \
# 1                           Compensation of employees  1,095,740  1,142,604
# 2                                  Wages and salaries    945,328    986,268
# 3                     Employers' social contributions    150,412    156,336
# 4                             Gross operating surplus    579,832    579,944
# 5                 Net operating surplus: corporations    284,812    270,080
# 6          Consumption of fixed capital: corporations    223,472    234,160
# 7   Consumption of fixed capital: general governme...     71,548     75,704
# 8                                  Gross mixed income    257,672    265,456
# 9                                    Net mixed income    194,124    199,452
# 10  Consumption of fixed capital: unincorporated b...     63,548     66,004
# 11               Taxes less subsidies on production 1     98,364     99,864
# ...

# %%
unemployment = pd.read_csv('C:/Users/user/Documents/DAB103/DAB103 Project Files/Unemployment.csv',skiprows=12,skipfooter=25,engine='python')
unemployment
# Out:
#    North American Industry Classification System (NAICS) 4        2017  2018  \
# 0                                                 NaN       Percentage   NaN
# 1                             Total, all industries 5              6.4   5.9
# 2                            Goods-producing sector 6              5.6     5
# 3                                       Agriculture 7              4.4     4
# 4   Forestry, fishing, mining, quarrying, oil and ...                8   6.9
# 5   Forestry and logging and support activities fo...             11.2  10.9
# 6                       Fishing, hunting and trapping             27.3  22.8
# 7     Mining, quarrying, and oil and gas extraction 8              5.6   4.8
# 8                                           Utilities              2.1   1.6
# 9                                        Construction              7.7   6.6
# 10                                      Manufacturing              3.7   3.6
# ...

# %%
clean_unemployment=unemployment.drop(columns=['Unnamed: 6','Unnamed: 7'],axis=1)
clean_unemployment=clean_unemployment.drop([0,29])
clean_unemployment
# Out:
#    North American Industry Classification System (NAICS) 4  2017  2018  2019  \
# 1                             Total, all industries 5        6.4   5.9   5.7
# 2                            Goods-producing sector 6        5.6     5   5.1
# 3                                       Agriculture 7        4.4     4   4.4
# 4   Forestry, fishing, mining, quarrying, oil and ...          8   6.9   7.4
# 5   Forestry and logging and support activities fo...       11.2  10.9  11.3
# 6                       Fishing, hunting and trapping       27.3  22.8  28.2
# 7     Mining, quarrying, and oil and gas extraction 8        5.6   4.8   4.9
# 8                                           Utilities        2.1   1.6   1.7
# 9                                        Construction        7.7   6.6   6.8
# 10                                      Manufacturing        3.7   3.6   3.7
# 11                                           Durables        3.4   3.3   3.4
# ...

# %%
clean_unemployment.sample(10)
# Out:
#    North American Industry Classification System (NAICS) 4 2017 2018 2019  \
# 16                                       Retail trade         4  4.1  4.1
# 7     Mining, quarrying, and oil and gas extraction 8       5.6  4.8  4.9
# 11                                           Durables       3.4  3.3  3.4
# 27      Other services (except public administration)       3.8  2.9  2.8
# 12                                       Non-durables       4.1  4.1  4.1
# 14                         Wholesale and retail trade       3.8  3.8  3.7
# 9                                        Construction       7.7  6.6  6.8
# 13                       Services-producing sector 10       3.5  3.3  3.3
# 10                                      Manufacturing       3.7  3.6  3.7
# 26                    Accommodation and food services       5.8  5.4  5.6
#
#     2020 2021
# 16   8.2  4.9
# 7    9.9  5.2
# 11   7.4  4.4
# 27   7.9  4.6
# 12   6.6  4.7
# 14   7.6  4.7
# 9    9.7  5.8
# 13   7.1  3.9
# ...

# %%
clean_unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28 entries, 1 to 28
# Data columns (total 6 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   North American Industry Classification System (NAICS) 4  28 non-null     object
#  1   2017                                                     28 non-null     object
#  2   2018                                                     28 non-null     object
#  3   2019                                                     28 non-null     object
#  4   2020                                                     28 non-null     object
#  5   2021                                                     28 non-null     object
# dtypes: object(6)
# memory usage: 1.5+ KB

# %%
unemployment_monthly = pd.read_csv('C:/Users/user/Documents/DAB103/DAB103 Project Files/Unemployment-Monthly.csv',skiprows=12,sep=',', quotechar='"', error_bad_lines=False,skipfooter=2,engine='python')
clean_UM=unemployment_monthly.drop([0])
# Out:
# Skipping line 56: ',' expected after '"'. Error could possibly be due to parsing errors in the skipped footer rows (the skipfooter keyword is only applied after Python's csv library has parsed all rows).
# Skipping line 63: ',' expected after '"'. Error could possibly be due to parsing errors in the skipped footer rows (the skipfooter keyword is only applied after Python's csv library has parsed all rows).

# %%
clean_UM
# Out:
#    North American Industry Classification System (NAICS) 4 January 2017  \
# 1                             Total, all industries 5               7.2
# 2                            Goods-producing sector 6               8.2
# 3                                       Agriculture 7               7.1
# 4   Forestry, fishing, mining, quarrying, oil and ...              10.1
# 5   Forestry and logging and support activities fo...              17.4
# 6                       Fishing, hunting and trapping              29.6
# 7     Mining, quarrying, and oil and gas extraction 8               7.2
# 8                                           Utilities               2.9
# 9                                        Construction              11.8
# 10                                      Manufacturing               5.4
# 11                                           Durables               5.3
# 12                                       Non-durables               5.6
# ...

# %%
clean_UM.describe()
# Out:
#        February 2017  June 2017  July 2017  August 2017  September 2017  \
# count      28.000000  28.000000  28.000000    28.000000       28.000000
# mean        6.196429   4.032143   4.610714     5.289286        4.392857
# std         5.461141   2.452520   3.743472     5.268659        5.269825
# min         1.300000   1.200000   1.500000     1.500000        0.900000
# 25%         3.250000   2.750000   2.750000     2.700000        2.375000
# 50%         4.500000   3.250000   3.700000     4.050000        3.300000
# 75%         7.000000   4.925000   5.025000     5.025000        4.675000
# max        27.300000  14.000000  21.500000    28.300000       30.300000
#
#        October 2017  November 2017  December 2017  January 2018  \
# count     28.000000      28.000000      28.000000     28.000000
# mean       4.578571       5.100000       4.817857      5.553571
# std        5.678964       6.643237       5.947739      5.856081
# ...

# %% [markdown]
# clean_UM.plot.scatter(x='February 2018',y='North American Industry Classification System (NAICS) 4',c='DarkBlue')
# clean_UM.plot.scatter(x='February 2017',y='North American Industry Classification System (NAICS) 4',c='DarkBlue')

# %%
clean_unemployment.dtypes
# Out:
# North American Industry Classification System (NAICS) 4    object
# 2017                                                       object
# 2018                                                       object
# 2019                                                       object
# 2020                                                       object
# 2021                                                       object
# dtype: object

# %%
clean_unemployment.isna().any()
# Out:
# North American Industry Classification System (NAICS) 4    False
# 2017                                                       False
# 2018                                                       False
# 2019                                                       False
# 2020                                                       False
# 2021                                                       False
# dtype: bool
